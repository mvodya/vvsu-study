# %% [markdown]
# # Лабораторная 1 - Преобразование Фурье
# ФИО: ... | Вариант: ...

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 13, 'figure.figsize': (10, 3.6), 'axes.grid': True, 'axes.unicode_minus': False})

# %% [markdown]
# ## 1. Исходные данные
# Номер варианта, массив одного периода и число повторов

# %%
variant = None  # TODO: номер варианта
period = np.array([], dtype=float)  # TODO: один блок своего варианта
repeats_list = [5, 20, 50]
fs = 1.0  # условная шкала: циклы/отсчет

# %% [markdown]
# ## 2. Массив сигнала
# Значения, форма массива и график двух периодов

# %%
# TODO: np.tile, print, fig/ax и временной график

# %% [markdown]
# ## 3. Спектры
# N, rFFT, частотная сетка, амплитуда и фаза для каждого числа повторов. Нормировка учитывает четность N

# %%
# TODO: расчет и графики для repeats_list

# %% [markdown]
# ## 4. Восстановление и сравнение
# Максимальная ошибка irFFT и таблица N, шага частот и амплитуд пиков

# %%
# TODO: irfft(X, n=N), таблица

# %% [markdown]
# ## 5. Вывод
# Изменения при увеличении числа повторов, единицы осей и выбор порога для фазового спектра
#
# ...
